# %% [markdown]
# ## 2D - No spatial transform

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/no_spatial_transform.py -h

# %%
# !python ../src/no_spatial_transform.py encode -h

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_spatial_transform.py encode
# rm /tmp/decoded.png
# python ../src/no_spatial_transform.py decode
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
