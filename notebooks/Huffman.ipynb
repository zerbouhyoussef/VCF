# %% [markdown]
# ## Huffman encoding
# See [zlib encoding](https://github.com/Sistemas-Multimedia/VCF/blob/main/notebooks/zlib.ipynb).

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/Huffman.py -h

# %%
# !python ../src/Huffman.py encode -h

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/Huffman.py encode

# %%
# !python ../src/Huffman.py decode -h

# %%
# %%bash
# python ../src/Huffman.py decode

# %%
display(Image(filename="/tmp/decoded.png"))

# %%
# %%bash
# python ../src/RDE.py
