# %% [markdown]
# ## TIFF encoding
# See [PNG encoding](https://github.com/Sistemas-Multimedia/VCF/blob/main/notebooks/PNG.ipynb).

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/TIFF.py -h

# %%
# !python ../src/TIFF.py encode -h

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/TIFF.py encode

# %%
# !file /tmp/encoded.tif

# %%
# !python ../src/TIFF.py decode -h

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/TIFF.py decode
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
