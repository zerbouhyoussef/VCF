# %% [markdown]
# ## Color DCT

# %%
from IPython.display import Image, display

# %%
# !rm /tmp/encoded*
# %run download_default_image.ipynb

# %%
# !python ../src/color-DCT.py encode -h

# %%
# !python ../src/color-DCT.py encode -q 16

# %%
# !python ../src/color-DCT.py decode -h

# %%
# !python ../src/color-DCT.py decode -q 16

# %%
display(Image(filename="/tmp/decoded.png"))

# %%
# !python ../src/RDE.py

# %% [markdown]
# ### Using LloydMax quantization

# %%
# !rm /tmp/encoded*
# !python ../src/color-DCT.py encode -a LloydMax -q 16 -m 0 -n 511
# !python ../src/color-DCT.py decode -a LloydMax -q 16 -m 0 -n 511
display(Image(filename="/tmp/decoded.png"))
# !python ../src/RDE.py

# %% [markdown]
# ### Using VQ quantization

# %%
# !rm /tmp/encoded*
# !python ../src/color-DCT.py encode -a VQ -b 8 -q 32
# !python ../src/color-DCT.py decode -a VQ -b 8 -q 32 -f gaussian_blur -s 5
display(Image(filename="/tmp/decoded.png"))
# !python ../src/RDE.py
