# %% [markdown]
# ## PNM (Portable aNy Map) encoding

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/PNM.py -h

# %%
# !python ../src/PNM.py encode -h

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/PNM.py encode

# %%
# !python ../src/PNM.py decode -h

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/PNM.py decode
# python ../src/RDE.py -c /tmp/encoded.pnm

# %%
display(Image(filename="/tmp/decoded.png"))
