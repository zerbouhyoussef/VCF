# %% [markdown]
# ## YCrCb color transform

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/YCrCb.py encode -h

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/YCrCb.py encode -q 32

# %%
# !python ../src/YCrCb.py decode -h

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/YCrCb.py decode -q 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using LloydMax quantization

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/YCrCb.py encode -a LloydMax
# rm /tmp/decoded.png
# python ../src/YCrCb.py decode -a LloydMax
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using (2D) VQ

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/YCrCb.py encode -a VQ -q 32
# rm /tmp/decoded.png
# python ../src/YCrCb.py decode -a VQ -q 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using VQ + Huffman

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/YCrCb.py encode -a VQ -c Huffman
# rm /tmp/decoded.png
# python ../src/YCrCb.py decode -a VQ -c Huffman
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
