# %% [markdown]
# ## No color transform

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/no_color_transform.py encode -h

# %%
# !rm /tmp/encoded*
# !python ../src/no_color_transform.py encode -q 32 # Deadzone's QSS

# %%
# !rm /tmp/decoded.png

# %%
# !python ../src/no_color_transform.py decode -h

# %%
# !python ../src/no_color_transform.py decode -q 32

# %%
display(Image(filename="/tmp/original.png"))
display(Image(filename="/tmp/decoded.png"))

# %%
# !python ../src/RDE.py

# %% [markdown]
# ### Using LloydMax quantization

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_color_transform.py encode -a LloydMax -q 32
# rm /tmp/decoded.png
# python ../src/no_color_transform.py decode -a LloydMax -q 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using (2D) VQ

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_color_transform.py encode -a VQ -q 32
# rm /tmp/decoded.png
# python ../src/no_color_transform.py decode -a VQ -q 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using a blur filter

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_color_transform.py encode -a VQ -q 32
# rm decoded.png
# python ../src/no_color_transform.py decode -a VQ -q 32 -f gaussian_blur -s 5
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
